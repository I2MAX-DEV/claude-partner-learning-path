# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 4.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Extract S3 Bucket Names from CloudFormation Template\n\nI'd be happy to help extract S3 bucket names from a CloudFormation template! However, I don't see the template content in your message.\n\nPlease provide the CloudFormation template (in JSON or YAML format), and I'll extract all S3 bucket names for you.\n\n## Example of what I can extract:\n\nFor a template like this:\n```yaml\nResources:\n  MyBucket:\n    Type: AWS::S3::Bucket\n    Properties:\n      BucketName: my-app-bucket\n  \n  LoggingBucket:\n    Type: AWS::S3::Bucket\n    Properties:\n      BucketName: my-logs-bucket\n```\n\nI would extract:\n- `my-app-bucket`\n- `my-logs-bucket`\n\n---\n\n**Please share your CloudFormation template** and I'll extract:\n1. Explicitly named S3 buckets\n2. Bucket logical IDs\n3. Any bucket references in properties\n4. Generated bucket names (if applicable)",
#     "test_case": {
#       "task": "Extract all S3 bucket names from AWS CloudFormation template output",
#       "format": "regex"
#     },
#     "score": 2,
#     "reasoning": "This response is primarily a request for input rather than a solution. While it demonstrates understanding of S3 bucket extraction conceptually, it provides no executable code, automation tool, or mechanism to parse CloudFormation templates programmatically. Additionally, it conflates CloudFormation templates with their outputs - the task specifically asks for extraction from 'output' which typically refers to the Outputs section or deployed resource properties, not template definitions. A proper solution would include a script (Python boto3, CLI commands, or similar) to actually extract and parse this information."
#   },
#   {
#     "output": "# AWS IAM Policy Parser\n\nHere's a comprehensive solution to parse AWS IAM policy documents and extract allowed actions:\n\n```python\nimport json\nfrom typing import List, Set, Union\n\ndef parse_iam_policy(policy: Union[str, dict]) -> List[str]:\n    \"\"\"\n    Parse an AWS IAM policy document and return a list of allowed actions.\n    \n    Args:\n        policy: IAM policy as a JSON string or dictionary\n        \n    Returns:\n        List of allowed actions\n        \n    Raises:\n        ValueError: If policy format is invalid\n        json.JSONDecodeError: If policy string is not valid JSON\n    \"\"\"\n    \n    # Convert string to dict if necessary\n    if isinstance(policy, str):\n        try:\n            policy = json.loads(policy)\n        except json.JSONDecodeError as e:\n            raise json.JSONDecodeError(f\"Invalid JSON policy: {e.msg}\", e.doc, e.pos)\n    \n    if not isinstance(policy, dict):\n        raise ValueError(\"Policy must be a dictionary or JSON string\")\n    \n    allowed_actions: Set[str] = set()\n    \n    # Handle both inline policies and assume role policies\n    statements = policy.get('Statement', [])\n    \n    if not isinstance(statements, list):\n        raise ValueError(\"Statement must be a list\")\n    \n    for statement in statements:\n        if not isinstance(statement, dict):\n            continue\n            \n        # Only process \"Allow\" statements\n        if statement.get('Effect') != 'Allow':\n            continue\n        \n        # Get Action(s) from the statement\n        actions = statement.get('Action', [])\n        \n        # Normalize to list\n        if isinstance(actions, str):\n            actions = [actions]\n        elif not isinstance(actions, list):\n            continue\n        \n        # Add all actions to the set\n        allowed_actions.update(actions)\n    \n    return sorted(list(allowed_actions))\n\n\n# Example usage and test cases\nif __name__ == \"__main__\":\n    \n    # Test 1: Basic policy with single action\n    policy1 = {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": \"arn:aws:s3:::my-bucket/*\"\n            }\n        ]\n    }\n    \n    print(\"Test 1 - Single Action:\")\n    print(parse_iam_policy(policy1))\n    print()\n    \n    # Test 2: Policy with multiple actions\n    policy2 = {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": [\n                    \"s3:GetObject\",\n                    \"s3:PutObject\",\n                    \"s3:DeleteObject\"\n                ],\n                \"Resource\": \"arn:aws:s3:::my-bucket/*\"\n            }\n        ]\n    }\n    \n    print(\"Test 2 - Multiple Actions:\")\n    print(parse_iam_policy(policy2))\n    print()\n    \n    # Test 3: Policy with multiple statements and Deny statements\n    policy3 = {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"ec2:*\",\n                \"Resource\": \"*\"\n            },\n            {\n                \"Effect\": \"Deny\",\n                \"Action\": \"ec2:TerminateInstances\",\n                \"Resource\": \"*\"\n            },\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": [\"iam:GetUser\", \"iam:ListUsers\"],\n                \"Resource\": \"*\"\n            }\n        ]\n    }\n    \n    print(\"Test 3 - Multiple Statements with Deny:\")\n    print(parse_iam_policy(policy3))\n    print()\n    \n    # Test 4: Policy as JSON string\n    policy4_json = '''\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"",
#     "test_case": {
#       "task": "Parse an AWS IAM policy document and return a list of allowed actions",
#       "format": "python"
#     },
#     "score": 6,
#     "reasoning": "The solution provides a solid foundation for basic IAM policy parsing with good error handling and correct filtering logic. However, it has notable limitations: it doesn't account for the inverse logic of 'NotAction' (where actions not listed are allowed), doesn't expand or process wildcard patterns, and the provided code is incomplete. For a production AWS tool, these omissions could lead to incorrect permission analysis. The core implementation is sound but incomplete for real-world IAM policy complexity."
#   },
#   {
#     "output": "# AWS Lambda Environment Variables Configuration (JSON)\n\nHere's a comprehensive JSON configuration template for AWS Lambda environment variables with database credentials:\n\n```json\n{\n  \"Variables\": {\n    \"ENVIRONMENT\": \"production\",\n    \"LOG_LEVEL\": \"INFO\",\n    \"DB_ENGINE\": \"mysql\",\n    \"DB_HOST\": \"mydb.c9akciq32.us-east-1.rds.amazonaws.com\",\n    \"DB_PORT\": \"3306\",\n    \"DB_NAME\": \"production_db\",\n    \"DB_USER\": \"admin\",\n    \"DB_PASSWORD\": \"{{resolve:secretsmanager:rds-credentials:SecretString:password}}\",\n    \"DB_POOL_SIZE\": \"10\",\n    \"DB_TIMEOUT\": \"5000\",\n    \"REDIS_HOST\": \"redis.cache.amazonaws.com\",\n    \"REDIS_PORT\": \"6379\",\n    \"REDIS_PASSWORD\": \"{{resolve:secretsmanager:redis-credentials:SecretString:password}}\",\n    \"API_KEY\": \"{{resolve:secretsmanager:api-keys:SecretString:key}}\",\n    \"JWT_SECRET\": \"{{resolve:secretsmanager:jwt-secret:SecretString:secret}}\",\n    \"REGION\": \"us-east-1\",\n    \"ACCOUNT_ID\": \"123456789012\",\n    \"ENABLE_ENCRYPTION\": \"true\"\n  }\n}\n```\n\n## Better Practice: Using AWS Secrets Manager References\n\n**Recommended approach** - Store sensitive data in AWS Secrets Manager:\n\n```json\n{\n  \"Variables\": {\n    \"ENVIRONMENT\": \"production\",\n    \"LOG_LEVEL\": \"INFO\",\n    \"DB_ENGINE\": \"mysql\",\n    \"DB_HOST\": \"mydb.c9akciq32.us-east-1.rds.amazonaws.com\",\n    \"DB_PORT\": \"3306\",\n    \"DB_NAME\": \"production_db\",\n    \"DB_USER\": \"{{resolve:secretsmanager:db-credentials:SecretString:username}}\",\n    \"DB_PASSWORD\": \"{{resolve:secretsmanager:db-credentials:SecretString:password}}\",\n    \"DB_POOL_SIZE\": \"10\",\n    \"REDIS_URL\": \"{{resolve:secretsmanager:redis-config:SecretString:connection_url}}\",\n    \"API_ENDPOINT\": \"https://api.example.com\",\n    \"REGION\": \"us-east-1\"\n  }\n}\n```\n\n## CloudFormation Template Example\n\n```yaml\nAWSTemplateFormatVersion: '2010-09-09'\nResources:\n  MyLambdaFunction:\n    Type: AWS::Lambda::Function\n    Properties:\n      FunctionName: my-database-function\n      Runtime: python3.11\n      Handler: index.handler\n      Role: arn:aws:iam::123456789012:role/lambda-execution-role\n      Environment:\n        Variables:\n          ENVIRONMENT: production\n          DB_HOST: !Sub '${RDSInstance.Endpoint.Address}'\n          DB_NAME: mydb\n          DB_USER: !Sub '{{resolve:secretsmanager:db-credentials:SecretString:username}}'\n          DB_PASSWORD: !Sub '{{resolve:secretsmanager:db-credentials:SecretString:password}}'\n          LOG_LEVEL: INFO\n```\n\n## Terraform Configuration\n\n```hcl\nresource \"aws_lambda_function\" \"database_function\" {\n  filename      = \"lambda_function.zip\"\n  function_name = \"my-database-function\"\n  role          = aws_iam_role.lambda_role.arn\n  handler       = \"index.handler\"\n  runtime       = \"python3.11\"\n\n  environment {\n    variables = {\n      ENVIRONMENT     = \"production\"\n      DB_HOST         = aws_db_instance.mysql.endpoint\n      DB_NAME         = \"production_db\"\n      DB_USER         = var.db_username\n      DB_PASSWORD     = var.db_password\n      LOG_LEVEL       = \"INFO\"\n    }\n  }\n}\n```\n\n## Security Best Practices\n\n```json\n{\n  \"Variables",
#     "test_case": {
#       "task": "Create a JSON configuration for AWS Lambda environment variables with database credentials",
#       "format": "json"
#     },
#     "score": 6,
#     "reasoning": "The solution demonstrates good understanding of AWS Lambda environment variable configuration and security best practices by recommending Secrets Manager. However, the response is incomplete with a truncated section, and the initial example contradicts its own security recommendations by hardcoding a username. The lack of IAM permission details and technical constraints (like the 4KB limit) further reduces practical utility. The multi-tool approach is valuable but doesn't compensate for these issues."
#   }
# ]
