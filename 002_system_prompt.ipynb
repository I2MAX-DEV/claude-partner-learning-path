# %%
# install dependencies  
# %pip install anthropic python-dotenv
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env Variable
from dotenv import load_dotenv

load_dotenv()

# Create an API Client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages,text):
    user_message = {"role":"user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages,text):
    assistant_message = {"role":"assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if(system):
        params["system"] = system
        
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []
add_user_message(messages, "How do I solve 5x+3=2 for x?")

# Without system prompt
answer = chat(messages)

print("Without system prompt:")
print(answer)

# With system prompt
system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""
answer = chat(messages, system=system)
print("With system prompt:")
print(answer)
# Out:
# Without system prompt:
# ## Solving 5x + 3 = 2
#
# **Goal:** Isolate x by undoing operations in reverse order.
#
# **Step 1: Subtract 3 from both sides**
# $$5x + 3 - 3 = 2 - 3$$
# $$5x = -1$$
#
# **Step 2: Divide both sides by 5**
# $$\frac{5x}{5} = \frac{-1}{5}$$
# $$x = -\frac{1}{5}$$
#
# ---
#
# **Check:** Plug x = -1/5 back into the original equation:
# - 5(-1/5) + 3 = -1 + 3 = **2** ✓
# With system prompt:
# Let's work through this together!
#
# Your goal is to **get x by itself** on one side of the equation.
#
# Let's start with the first step:
#
# **5x + 3 = 2**
#
# Right now, there's a **+3** on the same side as x. What could you do to both sides of the equation to start removing that 3? 🤔

# %%
# System prompt exercise Test

messages = []
add_user_message(messages, "Write a Pyhton function that checks a string for duplicate characters.",)

answer = chat(messages, system="You are a Python engineer who werites very concise code")

print(answer)
# Out:
# Here's a concise function that checks for duplicate characters:
#
# ```python
# def has_duplicates(s):
#     return len(s) != len(set(s))
# ```
#
# **Examples:**
# ```python
# print(has_duplicates("hello"))   # True  ('l' is duplicated)
# print(has_duplicates("world"))   # False (all unique)
# print(has_duplicates("python"))  # False (all unique)
# print(has_duplicates("abcabc"))  # True  (a, b, c are duplicated)
# ```
#
# If you also want to **return which characters are duplicated**:
#
# ```python
# def find_duplicates(s):
#     return {c for c in s if s.count(c) > 1}
# ```
#
# **Examples:**
# ```python
# print(find_duplicates("hello"))   # {'l'}
# print(find_duplicates("abcabc"))  # {'a', 'b', 'c'}
# print(find_duplicates("world"))   # set() (empty = no duplicates)
# ```
